# %% [markdown]
# # loading the data

# %%
import numpy as np 
import matplotlib.pyplot as plt

dn1 = np.load('dn1.npy')
ex1 = np.load('ex1.npy')
nx1 = np.load('nx1.npy')
dn2 = np.load('dn2.npy')
ex2 = np.load('ex2.npy')
nx2 = np.load('nx2.npy')
dn3 = np.load('dn3.npy')
ex3 = np.load('ex3.npy')
nx3 = np.load('nx3.npy')
r1 = np.load('result1.npy')
r2 = np.load('result_low.npy')
r3 = np.load('result_mid.npy')

# %%
r1 = np.squeeze(r1)
#r1 = np.transpose(r1,(1,0,2))
r1 = np.reshape(r1,(3,540,3))
r1 = r1[:,:,0]
r1.shape
# Out:
# (3, 540)

# %%
r2 = np.squeeze(r2)
#r2 = np.transpose(r2,(1,0,2))
r2 = np.reshape(r2,(3,540,3))
r2 = r2[:,:,1]
r2.shape
# Out:
# (3, 540)

# %%
r3 = np.squeeze(r3)
#r3 = np.transpose(r3,(1,0,2))
r3 = np.reshape(r3,(3,540,3))
r3 = r3[:,:,1]
r3.shape
# Out:
# (3, 540)

# %% [markdown]
# # Testing Earthquakes

# %%
import matplotlib.pyplot as plt

# Create a figure and subplots
fig, axs = plt.subplots(3, 1, figsize=(6, 8), sharex=True)

# Plot 1
axs[0].plot(ex1[0,:])
#axs[0].set_title('Plot 1')
axs[0].set_ylabel('Velocity [km/s]')
#axs[0].set_xlabel('Time [s]')

# Plot 2
axs[1].plot(ex1[1,:])
#axs[1].set_title('Plot 2')
axs[1].set_ylabel('Velocity [km/s]')
#axs[1].set_xlabel('Time [s]')

# Plot 3
axs[2].plot(ex1[2,:])
#axs[2].set_title('Plot 3')
axs[2].set_ylabel('Velocity [km/s]')
axs[2].set_xlabel('Time [s]')

# Adjust the spacing between subplots
plt.tight_layout()

# Display the figure with all three plots
plt.show()

# %%
import matplotlib.pyplot as plt

# Create a figure and subplots
fig, axs = plt.subplots(3, 1, figsize=(6, 8), sharex=True)

# Plot 1
axs[0].plot(nx1[0,:])
#axs[0].set_title('Plot 1')
axs[0].set_ylabel('Velocity [km/s]')
#axs[0].set_xlabel('Time [s]')

# Plot 2
axs[1].plot(nx1[1,:])
#axs[1].set_title('Plot 2')
axs[1].set_ylabel('Velocity [km/s]')
#axs[1].set_xlabel('Time [s]')

# Plot 3
axs[2].plot(nx1[2,:])
#axs[2].set_title('Plot 3')
axs[2].set_ylabel('Velocity [km/s]')
axs[2].set_xlabel('Time [s]')

# Adjust the spacing between subplots
plt.tight_layout()

# Display the figure with all three plots
plt.show()

# %%
import matplotlib.pyplot as plt

# Create a figure and subplots
fig, axs = plt.subplots(3, 1, figsize=(6, 8), sharex=True)

# Plot 1
axs[0].plot(dn1[0,:])
#axs[0].set_title('Plot 1')
axs[0].set_ylabel('Velocity [km/s]')
#axs[0].set_xlabel('Time [s]')

# Plot 2
axs[1].plot(dn1[1,:])
#axs[1].set_title('Plot 2')
axs[1].set_ylabel('Velocity [km/s]')
#axs[1].set_xlabel('Time [s]')

# Plot 3
axs[2].plot(dn1[2,:])
#axs[2].set_title('Plot 3')
axs[2].set_ylabel('Velocity [km/s]')
axs[2].set_xlabel('Time [s]')

# Adjust the spacing between subplots
plt.tight_layout()

# Display the figure with all three plots
plt.show()

# %%
import matplotlib.pyplot as plt

# Create a figure and subplots
fig, axs = plt.subplots(3, 1, figsize=(6, 8), sharex=True)

# Plot 1
axs[0].plot(r1[0,:])
#axs[0].set_title('Plot 1')
axs[0].set_ylabel('Velocity [km/s]')
#axs[0].set_xlabel('Time [s]')

# Plot 2
axs[1].plot(r1[1,:])
#axs[1].set_title('Plot 2')
axs[1].set_ylabel('Velocity [km/s]')
#axs[1].set_xlabel('Time [s]')

# Plot 3
axs[2].plot(r1[2,:])
#axs[2].set_title('Plot 3')
axs[2].set_ylabel('Velocity [km/s]')
axs[2].set_xlabel('Time [s]')

# Adjust the spacing between subplots
plt.tight_layout()

# Display the figure with all three plots
plt.show()
